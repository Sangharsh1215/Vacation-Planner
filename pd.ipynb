# %%
import http.client
import json  # Import the JSON module for parsing and formatting
import pandas as pd

# Connection to the SkyScanner API
conn = http.client.HTTPSConnection("sky-scanner3.p.rapidapi.com")

# Replace these with actual values
from_entity = "DEL"  # Origin (e.g., Paris)
to_entity = "BOM"  # Destination (e.g., London)
depart_date = "2025-02-26"  # Departure date (YYYY-MM-DD)
return_date = "2025-02-27"  # Return date (YYYY-MM-DD)

headers = {
    'x-rapidapi-key': "7f1bea6bb4msh78929f2c5e64eefp1988d4jsnece92c6405d1",
    'x-rapidapi-host': "sky-scanner3.p.rapidapi.com"
}

# Construct request with query parameters
url = f"/flights/search-roundtrip?fromEntityId={from_entity}&toEntityId={to_entity}&departDate={depart_date}&returnDate={return_date}&adults=1&currency=INR"

# Send GET request
conn.request("GET", url, headers=headers)

# Response
res = conn.getresponse()
data = res.read()

# Parse JSON and pretty-print
try:
    parsed_data = json.loads(data)  # Parse the JSON response
    pretty_json = json.dumps(parsed_data, indent=4)  # Format the JSON with 4 spaces of indentation
    print(pretty_json)
except json.JSONDecodeError:
    print("Failed to parse JSON response.")
# Out:
# {
#     "data": {
#         "context": {
#             "status": "incomplete",
#             "sessionId": "Cl0IARJZCk4KJDMxMzg2MDhiLTg3M2YtNDNlMS1hNWQyLWZhYmYzOGM1YjJiNhACGiQ5MDhkZjc4MC0yN2NkLTQ1OTgtYjRlMC04ZDk4NzkyMTNjNzgQ9tGJ078yGAESKHVzc181MDNhMWQ5MS0yZTg5LTQxMWMtOTQ4My1kNzk4NjQ4NmVmZDgiAlVT",
#             "totalResults": 10
#         },
#         "itineraries": [
#             {
#                 "id": "10957-2502260800--32213-0-10075-2502261020|10075-2502271900--32213-0-10957-2502272115",
#                 "price": {
#                     "raw": 9647.0,
#                     "formatted": "\u20b9\u00a09,647",
#                     "pricingOptionId": "09Y8ktX3va5s"
#                 },
#                 "legs": [
#                     {
#                         "id": "10957-2502260800--32213-0-10075-2502261020",
#                         "origin": {
#                             "id": "DEL",
#                             "entityId": "95673498",
#                             "name": "Indira Gandhi International ",
#                             "displayCode": "DEL",
#                             "city": "New Delhi",
#                             "country": "India",
#                             "isHighlighted": false
#                         },
#                         "destination": {
#                             "id": "BOM",
#                             "entityId": "95673320",
#                             "name": "Mumbai",
#                             "displayCode": "BOM",
#                             "city": "Mumbai",
#                             "country": "India",
#                             "isHighlighted": false
#                         },
#                         "durationInMinutes": 140,
#                         "stopCount": 0,
#                         "isSmallestStops": false,
#                         "departure": "2025-02-26T08:00:00",
#                         "arrival": "2025-02-26T10:20:00",
#                         "timeDeltaInDays": 0,
#                         "carriers": {
#                             "marketing": [
#                                 {
#                                     "id": -32213,
#                                     "alternateId": "49",
#                                     "logoUrl": "https://logos.skyscnr.com/images/airlines/favicon/49.png",
#                                     "name": "IndiGo"
#                                 }
#                             ],
#                             "operationType": "fully_operated"
#                         },
#                         "segments": [
#                             {
#                                 "id": "10957-10075-2502260800-2502261020--32213",
#                                 "origin": {
#                                     "flightPlaceId": "DEL",
#                                     "displayCode": "DEL",
#                                     "parent": {
#                                         "flightPlaceId": "IDEL",
#                                         "displayCode": "DEL",
#                                         "name": "New Delhi",
#                                         "type": "City"
#                                     },
#                                     "name": "Indira Gandhi International ",
#                                     "type": "Airport",
#                                     "country": "India"
#                                 },
#                                 "destination": {
#                                     "flightPlaceId": "BOM",
#                                     "displayCode": "BOM",
#                                     "parent": {
#                                         "flightPlaceId": "IBOM",
#                                         "displayCode": "BOM",
#                                         "name": "Mumbai",
#                                         "type": "City"
#                                     },
#                                     "name": "Mumbai",
#                                     "type": "Airport",
#                                     "country": "India"
#                                 },
#                                 "departure": "2025-02-26T08:00:00",
#                                 "arrival": "2025-02-26T10:20:00",
#                                 "durationInMinutes": 140,
#                                 "flightNumber": "675",
#                                 "marketingCarrier": {
#                                     "id": -32213,
#                                     "name": "IndiGo",
#                                     "alternateId": "49",
#                                     "allianceId": 0,
#                                     "displayCode": ""
#                                 },
#                                 "operatingCarrier": {
#                                     "id": -32213,
#                                     "name": "IndiGo",
#                                     "alternateId": "49",
#                                     "allianceId": 0,
#                                     "displayCode": ""
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "10075-2502271900--32213-0-10957-2502272115",
#                         "origin": {
#                             "id": "BOM",
#                             "entityId": "95673320",
#                             "name": "Mumbai",
#                             "displayCode": "BOM",
#                             "city": "Mumbai",
#                             "country": "India",
#                             "isHighlighted": false
#                         },
#                         "destination": {
#                             "id": "DEL",
#                             "entityId": "95673498",
#                             "name": "Indira Gandhi International ",
#                             "displayCode": "DEL",
#                             "city": "New Delhi",
#                             "country": "India",
#                             "isHighlighted": false
#                         },
#                         "durationInMinutes": 135,
#                         "stopCount": 0,
#                         "isSmallestStops": false,
#                         "departure": "2025-02-27T19:00:00",
#                         "arrival": "2025-02-27T21:15:00",
#                         "timeDeltaInDays": 0,
#                         "carriers": {
#                             "marketing": [
#                                 {
#                                     "id": -32213,
#                                     "alternateId": "49",
#                                     "logoUrl": "https://logos.skyscnr.com/images/airlines/favicon/49.png",
#                                     "name": "IndiGo"
#                                 }
#                             ],
#                             "operationType": "fully_operated"
#                         },
#                         "segments": [
#                             {
#                                 "id": "10075-10957-2502271900-2502272115--32213",
#                                 "origin": {
#                                     "flightPlaceId": "BOM",
#                                     "displayCode": "BOM",
#                                     "parent": {
#                                         "flightPlaceId": "IBOM",
#                                         "displayCode": "BOM",
#                                         "name": "Mumbai",
#                                         "type": "City"
#                                     },
#                                     "name": "Mumbai",
#                                     "type": "Airport",
#                                     "country": "India"
#                                 },
#                                 "destination": {
#                                     "flightPlaceId": "DEL",
#                                     "displayCode": "DEL",
#                                     "parent": {
#                                         "flightPlaceId": "IDEL",
#                                         "displayCode": "DEL",
#                                         "name": "New Delhi",
#                                         "type": "City"
#                                     },
#                                     "name": "Indira Gandhi International ",
#                                     "type": "Airport",
#                                     "country": "India"
#                                 },
#                                 "departure": "2025-02-27T19:00:00",
#                                 "arrival": "2025-02-27T21:15:00",
#                                 "durationInMinutes": 135,
#                                 "flightNumber": "6613",
#                                 "marketingCarrier": {
#                                     "id": -32213,
#                                     "name": "IndiGo",
#                                     "alternateId": "49",
#                                     "allianceId": 0,
#                                     "displayCode": ""
#                                 },
#                                 "operatingCarrier": {
#                                     "id": -32213,
#                                     "name": "IndiGo",
#                                     "alternateId": "49",
#                                     "allianceId": 0,
#                                     "displayCode": ""
#                                 }
#                             }
#                         ]
#                     }
#                 ],
#                 "isSelfTransfer": false,
#                 "isProtectedSelfTransfer": false,
#                 "farePolicy": {
#                     "isChangeAllowed": false,
#                     "isPartiallyChangeable": false,
#                     "isCancellationAllowed": false,
#                     "isPartiallyRefundable": false
#                 },
#                 "eco": {
#                     "ecoContenderDelta": 19.6702
#                 },
#                 "fareAttributes": {},
#                 "tags": [
#                     "second_cheapest",
#                     "third_shortest"
#                 ],
#                 "isMashUp": false,
#                 "hasFlexibleOptions": false,
#                 "score": 0.999
#             },
#             {
#                 "id": "10957-2502261000--32213-0-10075-2502261220|10075-2502271900--32213-0-10957-2502272115",
#                 "price": {
#                     "raw": 9647.0,
#                     "formatted": "\u20b9\u00a09,647",
#                     "pricingOptionId": "oRo4GUduNxeM"
#                 },
#                 "legs": [
#                     {
#                         "id": "10957-2502261000--32213-0-10075-2502261220",
#                         "origin": {
#                             "id": "DEL",
#                             "entityId": "95673498",
#                             "name": "Indira Gandhi International ",
#                             "displayCode": "DEL",
#                             "city": "New Delhi",
#                             "country": "India",
#                             "isHighlighted": false
#                         },
#                         "destination": {
#                             "id": "BOM",
#                             "entityId": "95673320",
#                             "name": "Mumbai",
#                             "displayCode": "BOM",
#                             "city": "Mumbai",
#                             "country": "India",
#                             "isHighlighted": false
#                         },
#                         "durationInMinutes": 140,
#                         "stopCount": 0,
#                         "isSmallestStops": false,
#                         "departure": "2025-02-26T10:00:00",
#                         "arrival": "2025-02-26T12:20:00",
#                         "timeDeltaInDays": 0,
#                         "carriers": {
#                             "marketing": [
#                                 {
#                                     "id": -32213,
#                                     "alternateId": "49",
#                                     "logoUrl": "https://logos.skyscnr.com/images/airlines/favicon/49.png",
#                                     "name": "IndiGo"
#                                 }
#                             ],
#                             "operationType": "fully_operated"
#                         },
#                         "segments": [
#                             {
#                                 "id": "10957-10075-2502261000-2502261220--32213",
#                                 "origin": {
#                                     "flightPlaceId": "DEL",
#                                     "displayCode": "DEL",
#                                     "parent": {
#                                         "flightPlaceId": "IDEL",
#                                         "displayCode": "DEL",
#                                         "name": "New Delhi",
#                                         "type": "City"
#                                     },
#                                     "name": "Indira Gandhi International ",
#                                     "type": "Airport",
#                                     "country": "India"
#                                 },
#                                 "destination": {
#                                     "flightPlaceId": "BOM",
#                                     "displayCode": "BOM",
#                                     "parent": {
#                                         "flightPlaceId": "IBOM",
#                                         "displayCode": "BOM",
#                                         "name": "Mumbai",
#                                         "type": "City"
#                                     },
#                                     "name": "Mumbai",
#                                     "type": "Airport",
#                                     "country": "India"
#                                 },
#                                 "departure": "2025-02-26T10:00:00",
#                                 "arrival": "2025-02-26T12:20:00",
#                                 "durationInMinutes": 140,
#                                 "flightNumber": "6328",
#                                 "marketingCarrier": {
#                                     "id": -32213,
#                                     "name": "IndiGo",
#                                     "alternateId": "49",
#                                     "allianceId": 0,
#                                     "displayCode": ""
#                                 },
#                                 "operatingCarrier": {
#                                     "id": -32213,
#                                     "name": "IndiGo",
#                                     "alternateId": "49",
#                                     "allianceId": 0,
#                                     "displayCode": ""
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "10075-2502271900--32213-0-10957-2502272115",
#                         "origin": {
#                             "id": "BOM",
#                             "entityId": "95673320",
#                             "name": "Mumbai",
#                             "displayCode": "BOM",
#                             "city": "Mumbai",
#                             "country": "India",
#                             "isHighlighted": false
#                         },
#                         "destination": {
#                             "id": "DEL",
#                             "entityId": "95673498",
#                             "name": "Indira Gandhi International ",
#                             "displayCode": "DEL",
#                             "city": "New Delhi",
#                             "country": "India",
#                             "isHighlighted": false
#                         },
#                         "durationInMinutes": 135,
#                         "stopCount": 0,
#                         "isSmallestStops": false,
#                         "departure": "2025-02-27T19:00:00",
#                         "arrival": "2025-02-27T21:15:00",
#                         "timeDeltaInDays": 0,
#                         "carriers": {
#                             "marketing": [
#                                 {
#                                     "id": -32213,
#                                     "alternateId": "49",
#                                     "logoUrl": "https://logos.skyscnr.com/images/airlines/favicon/49.png",
#                                     "name": "IndiGo"
#                                 }
#                             ],
#                             "operationType": "fully_operated"
#                         },
#                         "segments": [
#                             {
#                                 "id": "10075-10957-2502271900-2502272115--32213",
#                                 "origin": {
#                                     "flightPlaceId": "BOM",
#                                     "displayCode": "BOM",
#                                     "parent": {
#                                         "flightPlaceId": "IBOM",
#                                         "displayCode": "BOM",
#                                         "name": "Mumbai",
#                                         "type": "City"
#                                     },
#                                     "name": "Mumbai",
#                                     "type": "Airport",
#                                     "country": "India"
#                                 },
#                                 "destination": {
#                                     "flightPlaceId": "DEL",
#                                     "displayCode": "DEL",
#                                     "parent": {
#                                         "flightPlaceId": "IDEL",
#                                         "displayCode": "DEL",
#                                         "name": "New Delhi",
#                                         "type": "City"
#                                     },
#                                     "name": "Indira Gandhi International ",
#                                     "type": "Airport",
#                                     "country": "India"
#                                 },
#                                 "departure": "2025-02-27T19:00:00",
#                                 "arrival": "2025-02-27T21:15:00",
#                                 "durationInMinutes": 135,
#                                 "flightNumber": "6613",
#                                 "marketingCarrier": {
#                                     "id": -32213,
#                                     "name": "IndiGo",
#                                     "alternateId": "49",
#                                     "allianceId": 0,
#                                     "displayCode": ""
#                                 },
#                                 "operatingCarrier": {
#                                     "id": -32213,
#                                     "name": "IndiGo",
#                                     "alternateId": "49",
#                                     "allianceId": 0,
#                                     "displayCode": ""
#                                 }
#                             }
#                         ]
#                     }
#                 ],
#                 "isSelfTransfer": false,
#                 "isProtectedSelfTransfer": false,
#                 "farePolicy": {
#                     "isChangeAllowed": false,
#                     "isPartiallyChangeable": false,
#                     "isCancellationAllowed": false,
#                     "isPartiallyRefundable": false
#                 },
#                 "eco": {
#                     "ecoContenderDelta": 19.6702
#                 },
#                 "fareAttributes": {},
#                 "tags": [
#                     "second_cheapest",
#                     "third_shortest"
#                 ],
#                 "isMashUp": false,
#                 "hasFlexibleOptions": false,
#                 "score": 0.985747
#             },
#             {
#                 "id": "10957-2502261000--32213-0-10075-2502261220|10075-2502271700--32213-0-10957-2502271910",
#                 "price": {
#                     "raw": 9896.0,
#                     "formatted": "\u20b9\u00a09,896",
#                     "pricingOptionId": "oJa1eCov72F2"
#                 },
#                 "legs": [
#                     {
#                         "id": "10957-2502261000--32213-0-10075-2502261220",
#                         "origin": {
#                             "id": "DEL",
#                             "entityId": "95673498",
#                             "name": "Indira Gandhi International ",
#                             "displayCode": "DEL",
#                             "city": "New Delhi",
#                             "country": "India",
#                             "isHighlighted": false
#                         },
#                         "destination": {
#                             "id": "BOM",
#                             "entityId": "95673320",
#                             "name": "Mumbai",
#                             "displayCode": "BOM",
#                             "city": "Mumbai",
#                             "country": "India",
#                             "isHighlighted": false
#                         },
#                         "durationInMinutes": 140,
#                         "stopCount": 0,
#                         "isSmallestStops": false,
#                         "departure": "2025-02-26T10:00:00",
#                         "arrival": "2025-02-26T12:20:00",
#                         "timeDeltaInDays": 0,
#                         "carriers": {
#                             "marketing": [
#                                 {
#                                     "id": -32213,
#                                     "alternateId": "49",
#                                     "logoUrl": "https://logos.skyscnr.com/images/airlines/favicon/49.png",
#                                     "name": "IndiGo"
#                                 }
#                             ],
#                             "operationType": "fully_operated"
#                         },
#                         "segments": [
#                             {
#                                 "id": "10957-10075-2502261000-2502261220--32213",
#                                 "origin": {
#                                     "flightPlaceId": "DEL",
#                                     "displayCode": "DEL",
#                                     "parent": {
#                                         "flightPlaceId": "IDEL",
#                                         "displayCode": "DEL",
#                                         "name": "New Delhi",
#                                         "type": "City"
#                                     },
#                                     "name": "Indira Gandhi International ",
#                                     "type": "Airport",
#                                     "country": "India"
#                                 },
#                                 "destination": {
#                                     "flightPlaceId": "BOM",
#                                     "displayCode": "BOM",
#                                     "parent": {
#                                         "flightPlaceId": "IBOM",
#                                         "displayCode": "BOM",
#                                         "name": "Mumbai",
#                                         "type": "City"
#                                     },
#                                     "name": "Mumbai",
#                                     "type": "Airport",
#                                     "country": "India"
#                                 },
#                                 "departure": "2025-02-26T10:00:00",
#                                 "arrival": "2025-02-26T12:20:00",
#                                 "durationInMinutes": 140,
#                                 "flightNumber": "6328",
#                                 "marketingCarrier": {
#                                     "id": -32213,
#                                     "name": "IndiGo",
#                                     "alternateId": "49",
#                                     "allianceId": 0,
#                                     "displayCode": ""
#                                 },
#                                 "operatingCarrier": {
#                                     "id": -32213,
#                                     "name": "IndiGo",
#                                     "alternateId": "49",
#                                     "allianceId": 0,
#                                     "displayCode": ""
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "10075-2502271700--32213-0-10957-2502271910",
#                         "origin": {
#                             "id": "BOM",
#                             "entityId": "95673320",
#                             "name": "Mumbai",
#                             "displayCode": "BOM",
#                             "city": "Mumbai",
#                             "country": "India",
#                             "isHighlighted": false
#                         },
#                         "destination": {
#                             "id": "DEL",
#                             "entityId": "95673498",
#                             "name": "Indira Gandhi International ",
#                             "displayCode": "DEL",
#                             "city": "New Delhi",
#                             "country": "India",
#                             "isHighlighted": false
#                         },
#                         "durationInMinutes": 130,
#                         "stopCount": 0,
#                         "isSmallestStops": false,
#                         "departure": "2025-02-27T17:00:00",
#                         "arrival": "2025-02-27T19:10:00",
#                         "timeDeltaInDays": 0,
#                         "carriers": {
#                             "marketing": [
#                                 {
#                                     "id": -32213,
#                                     "alternateId": "49",
#                                     "logoUrl": "https://logos.skyscnr.com/images/airlines/favicon/49.png",
#                                     "name": "IndiGo"
#                                 }
#                             ],
#                             "operationType": "fully_operated"
#                         },
#                         "segments": [
#                             {
#                                 "id": "10075-10957-2502271700-2502271910--32213",
#                                 "origin": {
#                                     "flightPlaceId": "BOM",
#                                     "displayCode": "BOM",
#                                     "parent": {
#                                         "flightPlaceId": "IBOM",
#                                         "displayCode": "BOM",
#                                         "name": "Mumbai",
#                                         "type": "City"
#                                     },
#                                     "name": "Mumbai",
#                                     "type": "Airport",
#                                     "country": "India"
#                                 },
#                                 "destination": {
#                                     "flightPlaceId": "DEL",
#                                     "displayCode": "DEL",
#                                     "parent": {
#                                         "flightPlaceId": "IDEL",
#                                         "displayCode": "DEL",
#                                         "name": "New Delhi",
#                                         "type": "City"
#                                     },
#                                     "name": "Indira Gandhi International ",
#                                     "type": "Airport",
#                                     "country": "India"
#                                 },
#                                 "departure": "2025-02-27T17:00:00",
#                                 "arrival": "2025-02-27T19:10:00",
#                                 "durationInMinutes": 130,
#                                 "flightNumber": "733",
#                                 "marketingCarrier": {
#                                     "id": -32213,
#                                     "name": "IndiGo",
#                                     "alternateId": "49",
#                                     "allianceId": 0,
#                                     "displayCode": ""
#                                 },
#                                 "operatingCarrier": {
#                                     "id": -32213,
#                                     "name": "IndiGo",
#                                     "alternateId": "49",
#                                     "allianceId": 0,
#                                     "displayCode": ""
#                                 }
#                             }
#                         ]
#                     }
#                 ],
#                 "isSelfTransfer": false,
#                 "isProtectedSelfTransfer": false,
#                 "farePolicy": {
#                     "isChangeAllowed": false,
#                     "isPartiallyChangeable": false,
#                     "isCancellationAllowed": false,
#                     "isPartiallyRefundable": false
#                 },
#                 "eco": {
#                     "ecoContenderDelta": 19.6702
#                 },
#                 "fareAttributes": {},
#                 "tags": [
#                     "third_cheapest",
#                     "second_shortest"
#                 ],
#                 "isMashUp": false,
#                 "hasFlexibleOptions": false,
#                 "score": 0.971447
#             },
#             {
#                 "id": "10957-2502260700--32213-0-10075-2502260915|10075-2502271900--32213-0-10957-2502272115",
#                 "price": {
#                     "raw": 9647.0,
#                     "formatted": "\u20b9\u00a09,647",
#                     "pricingOptionId": "oaWq36GbQSs7"
#                 },
#                 "legs": [
#                     {
#                         "id": "10957-2502260700--32213-0-10075-2502260915",
#                         "origin": {
#                             "id": "DEL",
#                             "entityId": "95673498",
#                             "name": "Indira Gandhi International ",
#                             "displayCode": "DEL",
#                             "city": "New Delhi",
#                             "country": "India",
#                             "isHighlighted": false
#                         },
#                         "destination": {
#                             "id": "BOM",
#                             "entityId": "95673320",
#                             "name": "Mumbai",
#                             "displayCode": "BOM",
#                             "city": "Mumbai",
#                             "country": "India",
#                             "isHighlighted": false
#                         },
#                         "durationInMinutes": 135,
#                         "stopCount": 0,
#                         "isSmallestStops": false,
#                         "departure": "2025-02-26T07:00:00",
#                         "arrival": "2025-02-26T09:15:00",
#                         "timeDeltaInDays": 0,
#                         "carriers": {
#                             "marketing": [
#                                 {
#                                     "id": -32213,
#                                     "alternateId": "49",
#                                     "logoUrl": "https://logos.skyscnr.com/images/airlines/favicon/49.png",
#                                     "name": "IndiGo"
#                                 }
#                             ],
#                             "operationType": "fully_operated"
#                         },
#                         "segments": [
#                             {
#                                 "id": "10957-10075-2502260700-2502260915--32213",
#                                 "origin": {
#                                     "flightPlaceId": "DEL",
#                                     "displayCode": "DEL",
#                                     "parent": {
#                                         "flightPlaceId": "IDEL",
#                                         "displayCode": "DEL",
#                                         "name": "New Delhi",
#                                         "type": "City"
#                                     },
#                                     "name": "Indira Gandhi International ",
#                                     "type": "Airport",
#                                     "country": "India"
#                                 },
#                                 "destination": {
#                                     "flightPlaceId": "BOM",
#                                     "displayCode": "BOM",
#                                     "parent": {
#                                         "flightPlaceId": "IBOM",
#                                         "displayCode": "BOM",
#                                         "name": "Mumbai",
#                                         "type": "City"
#                                     },
#                                     "name": "Mumbai",
#                                     "type": "Airport",
#                                     "country": "India"
#                                 },
#                                 "departure": "2025-02-26T07:00:00",
#                                 "arrival": "2025-02-26T09:15:00",
#                                 "durationInMinutes": 135,
#                                 "flightNumber": "6814",
#                                 "marketingCarrier": {
#                                     "id": -32213,
#                                     "name": "IndiGo",
#                                     "alternateId": "49",
#                                     "allianceId": 0,
#                                     "displayCode": ""
#                                 },
#                                 "operatingCarrier": {
#                                     "id": -32213,
#                                     "name": "IndiGo",
#                                     "alternateId": "49",
#                                     "allianceId": 0,
#                                     "displayCode": ""
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "10075-2502271900--32213-0-10957-2502272115",
#                         "origin": {
#                             "id": "BOM",
#                             "entityId": "95673320",
#                             "name": "Mumbai",
#                             "displayCode": "BOM",
#                             "city": "Mumbai",
#                             "country": "India",
#                             "isHighlighted": false
#                         },
#                         "destination": {
#                             "id": "DEL",
#                             "entityId": "95673498",
#                             "name": "Indira Gandhi International ",
#                             "displayCode": "DEL",
#                             "city": "New Delhi",
#                             "country": "India",
#                             "isHighlighted": false
#                         },
#                         "durationInMinutes": 135,
#                         "stopCount": 0,
#                         "isSmallestStops": false,
#                         "departure": "2025-02-27T19:00:00",
#                         "arrival": "2025-02-27T21:15:00",
#                         "timeDeltaInDays": 0,
#                         "carriers": {
#                             "marketing": [
#                                 {
#                                     "id": -32213,
#                                     "alternateId": "49",
#                                     "logoUrl": "https://logos.skyscnr.com/images/airlines/favicon/49.png",
#                                     "name": "IndiGo"
#                                 }
#                             ],
#                             "operationType": "fully_operated"
#                         },
#                         "segments": [
#                             {
#                                 "id": "10075-10957-2502271900-2502272115--32213",
#                                 "origin": {
#                                     "flightPlaceId": "BOM",
#                                     "displayCode": "BOM",
#                                     "parent": {
#                                         "flightPlaceId": "IBOM",
#                                         "displayCode": "BOM",
#                                         "name": "Mumbai",
#                                         "type": "City"
#                                     },
#                                     "name": "Mumbai",
#                                     "type": "Airport",
#                                     "country": "India"
#                                 },
#                                 "destination": {
#                                     "flightPlaceId": "DEL",
#                                     "displayCode": "DEL",
#                                     "parent": {
#                                         "flightPlaceId": "IDEL",
#                                         "displayCode": "DEL",
#                                         "name": "New Delhi",
#                                         "type": "City"
#                                     },
#                                     "name": "Indira Gandhi International ",
#                                     "type": "Airport",
#                                     "country": "India"
#                                 },
#                                 "departure": "2025-02-27T19:00:00",
#                                 "arrival": "2025-02-27T21:15:00",
#                                 "durationInMinutes": 135,
#                                 "flightNumber": "6613",
#                                 "marketingCarrier": {
#                                     "id": -32213,
#                                     "name": "IndiGo",
#                                     "alternateId": "49",
#                                     "allianceId": 0,
#                                     "displayCode": ""
#                                 },
#                                 "operatingCarrier": {
#                                     "id": -32213,
#                                     "name": "IndiGo",
#                                     "alternateId": "49",
#                                     "allianceId": 0,
#                                     "displayCode": ""
#                                 }
#                             }
#                         ]
#                     }
#                 ],
#                 "isSelfTransfer": false,
#                 "isProtectedSelfTransfer": false,
#                 "farePolicy": {
#                     "isChangeAllowed": false,
#                     "isPartiallyChangeable": false,
#                     "isCancellationAllowed": false,
#                     "isPartiallyRefundable": false
#                 },
#                 "eco": {
#                     "ecoContenderDelta": 19.6702
#                 },
#                 "fareAttributes": {},
#                 "tags": [
#                     "cheapest",
#                     "shortest"
#                 ],
#                 "isMashUp": false,
#                 "hasFlexibleOptions": false,
#                 "score": 0.956762
#             },
#             {
#                 "id": "10957-2502260800--32213-0-10075-2502261020|10075-2502272000--32213-0-10957-2502272210",
#                 "price": {
#                     "raw": 9647.0,
#                     "formatted": "\u20b9\u00a09,647",
#                     "pricingOptionId": "16p6thXJjbtJ"
#                 },
#                 "legs": [
#                     {
#                         "id": "10957-2502260800--32213-0-10075-2502261020",
#                         "origin": {
#                             "id": "DEL",
#                             "entityId": "95673498",
#                             "name": "Indira Gandhi International ",
#                             "displayCode": "DEL",
#                             "city": "New Delhi",
#                             "country": "India",
#                             "isHighlighted": false
#                         },
#                         "destination": {
#                             "id": "BOM",
#                             "entityId": "95673320",
#                             "name": "Mumbai",
#                             "displayCode": "BOM",
#                             "city": "Mumbai",
#                             "country": "India",
#                             "isHighlighted": false
#                         },
#                         "durationInMinutes": 140,
#                         "stopCount": 0,
#                         "isSmallestStops": false,
#                         "departure": "2025-02-26T08:00:00",
#                         "arrival": "2025-02-26T10:20:00",
#                         "timeDeltaInDays": 0,
#                         "carriers": {
#                             "marketing": [
#                                 {
#                                     "id": -32213,
#                                     "alternateId": "49",
#                                     "logoUrl": "https://logos.skyscnr.com/images/airlines/favicon/49.png",
#                                     "name": "IndiGo"
#                                 }
#                             ],
#                             "operationType": "fully_operated"
#                         },
#                         "segments": [
#                             {
#                                 "id": "10957-10075-2502260800-2502261020--32213",
#                                 "origin": {
#                                     "flightPlaceId": "DEL",
#                                     "displayCode": "DEL",
#                                     "parent": {
#                                         "flightPlaceId": "IDEL",
#                                         "displayCode": "DEL",
#                                         "name": "New Delhi",
#                                         "type": "City"
#                                     },
#                                     "name": "Indira Gandhi International ",
#                                     "type": "Airport",
#                                     "country": "India"
#                                 },
#                                 "destination": {
#                                     "flightPlaceId": "BOM",
#                                     "displayCode": "BOM",
#                                     "parent": {
#                                         "flightPlaceId": "IBOM",
#                                         "displayCode": "BOM",
#                                         "name": "Mumbai",
#                                         "type": "City"
#                                     },
#                                     "name": "Mumbai",
#                                     "type": "Airport",
#                                     "country": "India"
#                                 },
#                                 "departure": "2025-02-26T08:00:00",
#                                 "arrival": "2025-02-26T10:20:00",
#                                 "durationInMinutes": 140,
#                                 "flightNumber": "675",
#                                 "marketingCarrier": {
#                                     "id": -32213,
#                                     "name": "IndiGo",
#                                     "alternateId": "49",
#                                     "allianceId": 0,
#                                     "displayCode": ""
#                                 },
#                                 "operatingCarrier": {
#                                     "id": -32213,
#                                     "name": "IndiGo",
#                                     "alternateId": "49",
#                                     "allianceId": 0,
#                                     "displayCode": ""
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "10075-2502272000--32213-0-10957-2502272210",
#                         "origin": {
#                             "id": "BOM",
#                             "entityId": "95673320",
#                             "name": "Mumbai",
#                             "displayCode": "BOM",
#                             "city": "Mumbai",
#                             "country": "India",
#                             "isHighlighted": false
#                         },
#                         "destination": {
#                             "id": "DEL",
#                             "entityId": "95673498",
#                             "name": "Indira Gandhi International ",
#                             "displayCode": "DEL",
#                             "city": "New Delhi",
#                             "country": "India",
#                             "isHighlighted": false
#                         },
#                         "durationInMinutes": 130,
#                         "stopCount": 0,
#                         "isSmallestStops": false,
#                         "departure": "2025-02-27T20:00:00",
#                         "arrival": "2025-02-27T22:10:00",
#                         "timeDeltaInDays": 0,
#                         "carriers": {
#                             "marketing": [
#                                 {
#                                     "id": -32213,
#                                     "alternateId": "49",
#                                     "logoUrl": "https://logos.skyscnr.com/images/airlines/favicon/49.png",
#                                     "name": "IndiGo"
#                                 }
#                             ],
#                             "operationType": "fully_operated"
#                         },
#                         "segments": [
#                             {
#                                 "id": "10075-10957-2502272000-2502272210--32213",
#                                 "origin": {
#                                     "flightPlaceId": "BOM",
#                                     "displayCode": "BOM",
#                                     "parent": {
#                                         "flightPlaceId": "IBOM",
#                                         "displayCode": "BOM",
#                                         "name": "Mumbai",
#                                         "type": "City"
#                                     },
#                                     "name": "Mumbai",
#                                     "type": "Airport",
#                                     "country": "India"
#                                 },
#                                 "destination": {
#                                     "flightPlaceId": "DEL",
#                                     "displayCode": "DEL",
#                                     "parent": {
#                                         "flightPlaceId": "IDEL",
#                                         "displayCode": "DEL",
#                                         "name": "New Delhi",
#                                         "type": "City"
#                                     },
#                                     "name": "Indira Gandhi International ",
#                                     "type": "Airport",
#                                     "country": "India"
#                                 },
#                                 "departure": "2025-02-27T20:00:00",
#                                 "arrival": "2025-02-27T22:10:00",
#                                 "durationInMinutes": 130,
#                                 "flightNumber": "697",
#                                 "marketingCarrier": {
#                                     "id": -32213,
#                                     "name": "IndiGo",
# ...
#                         },
#                         "durationInMinutes": 130,
#                         "stopCount": 0,
#                         "isSmallestStops": false,
#                         "departure": "2025-02-27T18:00:00",
#                         "arrival": "2025-02-27T20:10:00",
#                         "timeDeltaInDays": 0,
#                         "carriers": {
#                             "marketing": [
#                                 {
#                                     "id": -32213,
#                                     "alternateId": "49",
#                                     "logoUrl": "https://logos.skyscnr.com/images/airlines/favicon/49.png",
#                                     "name": "IndiGo"
#                                 }
#                             ],
#                             "operationType": "fully_operated"
#                         },
#                         "segments": [
#                             {
#                                 "id": "10075-10957-2502271800-2502272010--32213",
#                                 "origin": {
#                                     "flightPlaceId": "BOM",
#                                     "displayCode": "BOM",
#                                     "parent": {
#                                         "flightPlaceId": "IBOM",
#                                         "displayCode": "BOM",
#                                         "name": "Mumbai",
#                                         "type": "City"
#                                     },
#                                     "name": "Mumbai",
#                                     "type": "Airport",
#                                     "country": "India"
#                                 },
#                                 "destination": {
#                                     "flightPlaceId": "DEL",
#                                     "displayCode": "DEL",
#                                     "parent": {
#                                         "flightPlaceId": "IDEL",
#                                         "displayCode": "DEL",
#                                         "name": "New Delhi",
#                                         "type": "City"
#                                     },
#                                     "name": "Indira Gandhi International ",
#                                     "type": "Airport",
#                                     "country": "India"
#                                 },
#                                 "departure": "2025-02-27T18:00:00",
#                                 "arrival": "2025-02-27T20:10:00",
#                                 "durationInMinutes": 130,
#                                 "flightNumber": "6082",
#                                 "marketingCarrier": {
#                                     "id": -32213,
#                                     "name": "IndiGo",
#                                     "alternateId": "49",
#                                     "allianceId": 0,
#                                     "displayCode": ""
#                                 },
#                                 "operatingCarrier": {
#                                     "id": -32213,
#                                     "name": "IndiGo",
#                                     "alternateId": "49",
#                                     "allianceId": 0,
#                                     "displayCode": ""
#                                 }
#                             }
#                         ]
#                     }
#                 ],
#                 "isSelfTransfer": false,
#                 "isProtectedSelfTransfer": false,
#                 "farePolicy": {
#                     "isChangeAllowed": false,
#                     "isPartiallyChangeable": false,
#                     "isCancellationAllowed": false,
#                     "isPartiallyRefundable": false
#                 },
#                 "eco": {
#                     "ecoContenderDelta": 19.6702
#                 },
#                 "fareAttributes": {},
#                 "tags": [
#                     "third_cheapest",
#                     "second_shortest"
#                 ],
#                 "isMashUp": false,
#                 "hasFlexibleOptions": false,
#                 "score": 0.954262
#             },
#             {
#                 "id": "10957-2502260800--32213-0-10075-2502261020|10075-2502271700--32213-0-10957-2502271910",
#                 "price": {
#                     "raw": 9896.0,
#                     "formatted": "\u20b9\u00a09,896",
#                     "pricingOptionId": "yTV_TWVfe2yG"
#                 },
#                 "legs": [
#                     {
#                         "id": "10957-2502260800--32213-0-10075-2502261020",
#                         "origin": {
#                             "id": "DEL",
#                             "entityId": "95673498",
#                             "name": "Indira Gandhi International ",
#                             "displayCode": "DEL",
#                             "city": "New Delhi",
#                             "country": "India",
#                             "isHighlighted": false
#                         },
#                         "destination": {
#                             "id": "BOM",
#                             "entityId": "95673320",
#                             "name": "Mumbai",
#                             "displayCode": "BOM",
#                             "city": "Mumbai",
#                             "country": "India",
#                             "isHighlighted": false
#                         },
#                         "durationInMinutes": 140,
#                         "stopCount": 0,
#                         "isSmallestStops": false,
#                         "departure": "2025-02-26T08:00:00",
#                         "arrival": "2025-02-26T10:20:00",
#                         "timeDeltaInDays": 0,
#                         "carriers": {
#                             "marketing": [
#                                 {
#                                     "id": -32213,
#                                     "alternateId": "49",
#                                     "logoUrl": "https://logos.skyscnr.com/images/airlines/favicon/49.png",
#                                     "name": "IndiGo"
#                                 }
#                             ],
#                             "operationType": "fully_operated"
#                         },
#                         "segments": [
#                             {
#                                 "id": "10957-10075-2502260800-2502261020--32213",
#                                 "origin": {
#                                     "flightPlaceId": "DEL",
#                                     "displayCode": "DEL",
#                                     "parent": {
#                                         "flightPlaceId": "IDEL",
#                                         "displayCode": "DEL",
#                                         "name": "New Delhi",
#                                         "type": "City"
#                                     },
#                                     "name": "Indira Gandhi International ",
#                                     "type": "Airport",
#                                     "country": "India"
#                                 },
#                                 "destination": {
#                                     "flightPlaceId": "BOM",
#                                     "displayCode": "BOM",
#                                     "parent": {
#                                         "flightPlaceId": "IBOM",
#                                         "displayCode": "BOM",
#                                         "name": "Mumbai",
#                                         "type": "City"
#                                     },
#                                     "name": "Mumbai",
#                                     "type": "Airport",
#                                     "country": "India"
#                                 },
#                                 "departure": "2025-02-26T08:00:00",
#                                 "arrival": "2025-02-26T10:20:00",
#                                 "durationInMinutes": 140,
#                                 "flightNumber": "675",
#                                 "marketingCarrier": {
#                                     "id": -32213,
#                                     "name": "IndiGo",
#                                     "alternateId": "49",
#                                     "allianceId": 0,
#                                     "displayCode": ""
#                                 },
#                                 "operatingCarrier": {
#                                     "id": -32213,
#                                     "name": "IndiGo",
#                                     "alternateId": "49",
#                                     "allianceId": 0,
#                                     "displayCode": ""
#                                 }
#                             }
#                         ]
#                     },
#                     {
#                         "id": "10075-2502271700--32213-0-10957-2502271910",
#                         "origin": {
#                             "id": "BOM",
#                             "entityId": "95673320",
#                             "name": "Mumbai",
#                             "displayCode": "BOM",
#                             "city": "Mumbai",
#                             "country": "India",
#                             "isHighlighted": false
#                         },
#                         "destination": {
#                             "id": "DEL",
#                             "entityId": "95673498",
#                             "name": "Indira Gandhi International ",
#                             "displayCode": "DEL",
#                             "city": "New Delhi",
#                             "country": "India",
#                             "isHighlighted": false
#                         },
#                         "durationInMinutes": 130,
#                         "stopCount": 0,
#                         "isSmallestStops": false,
#                         "departure": "2025-02-27T17:00:00",
#                         "arrival": "2025-02-27T19:10:00",
#                         "timeDeltaInDays": 0,
#                         "carriers": {
#                             "marketing": [
#                                 {
#                                     "id": -32213,
#                                     "alternateId": "49",
#                                     "logoUrl": "https://logos.skyscnr.com/images/airlines/favicon/49.png",
#                                     "name": "IndiGo"
#                                 }
#                             ],
#                             "operationType": "fully_operated"
#                         },
#                         "segments": [
#                             {
#                                 "id": "10075-10957-2502271700-2502271910--32213",
#                                 "origin": {
#                                     "flightPlaceId": "BOM",
#                                     "displayCode": "BOM",
#                                     "parent": {
#                                         "flightPlaceId": "IBOM",
#                                         "displayCode": "BOM",
#                                         "name": "Mumbai",
#                                         "type": "City"
#                                     },
#                                     "name": "Mumbai",
#                                     "type": "Airport",
#                                     "country": "India"
#                                 },
#                                 "destination": {
#                                     "flightPlaceId": "DEL",
#                                     "displayCode": "DEL",
#                                     "parent": {
#                                         "flightPlaceId": "IDEL",
#                                         "displayCode": "DEL",
#                                         "name": "New Delhi",
#                                         "type": "City"
#                                     },
#                                     "name": "Indira Gandhi International ",
#                                     "type": "Airport",
#                                     "country": "India"
#                                 },
#                                 "departure": "2025-02-27T17:00:00",
#                                 "arrival": "2025-02-27T19:10:00",
#                                 "durationInMinutes": 130,
#                                 "flightNumber": "733",
#                                 "marketingCarrier": {
#                                     "id": -32213,
#                                     "name": "IndiGo",
#                                     "alternateId": "49",
#                                     "allianceId": 0,
#                                     "displayCode": ""
#                                 },
#                                 "operatingCarrier": {
#                                     "id": -32213,
#                                     "name": "IndiGo",
#                                     "alternateId": "49",
#                                     "allianceId": 0,
#                                     "displayCode": ""
#                                 }
#                             }
#                         ]
#                     }
#                 ],
#                 "isSelfTransfer": false,
#                 "isProtectedSelfTransfer": false,
#                 "farePolicy": {
#                     "isChangeAllowed": false,
#                     "isPartiallyChangeable": false,
#                     "isCancellationAllowed": false,
#                     "isPartiallyRefundable": false
#                 },
#                 "eco": {
#                     "ecoContenderDelta": 19.6702
#                 },
#                 "fareAttributes": {},
#                 "tags": [
#                     "third_cheapest",
#                     "second_shortest"
#                 ],
#                 "isMashUp": false,
#                 "hasFlexibleOptions": false,
#                 "score": 0.954144
#             }
#         ],
#         "messages": [],
#         "filterStats": {
#             "duration": {
#                 "min": 135,
#                 "max": 140,
#                 "multiCityMin": 270,
#                 "multiCityMax": 275
#             },
#             "airports": [
#                 {
#                     "city": "Mumbai",
#                     "airports": [
#                         {
#                             "id": "BOM",
#                             "entityId": "95673320",
#                             "name": "Mumbai"
#                         }
#                     ]
#                 },
#                 {
#                     "city": "New Delhi",
#                     "airports": [
#                         {
#                             "id": "DEL",
#                             "entityId": "95673498",
#                             "name": "Indira Gandhi International "
#                         }
#                     ]
#                 }
#             ],
#             "carriers": [
#                 {
#                     "id": -32213,
#                     "alternateId": "49",
#                     "logoUrl": "https://logos.skyscnr.com/images/airlines/favicon/49.png",
#                     "name": "IndiGo"
#                 }
#             ],
#             "stopPrices": {
#                 "direct": {
#                     "isPresent": true,
#                     "formattedPrice": "\u20b9\u00a09,647"
#                 },
#                 "one": {
#                     "isPresent": false
#                 },
#                 "twoOrMore": {
#                     "isPresent": false
#                 }
#             }
#         },
#         "flightsSessionId": "3138608b-873f-43e1-a5d2-fabf38c5b2b6",
#         "destinationImageUrl": "https://content.skyscnr.com/m/3719e8f4a5daf43d/original/Flights-Placeholder.jpg",
#         "token": "eyJhIjoxLCJjIjowLCJpIjowLCJjYyI6ImVjb25vbXkiLCJvIjoiREVMIiwiZCI6IkJPTSIsImQxIjoiMjAyNS0wMi0yNiIsImQyIjoiMjAyNS0wMi0yNyJ9"
#     },
#     "status": true,
#     "message": "Successful"
# }

# %%
# Convert parsed JSON data into a DataFrame for easy manipulation
def process_itinerary_data(parsed_data):
    try:
        # Extract itineraries from the parsed JSON
        itineraries = parsed_data.get('data', {}).get('itineraries', [])
        processed_data = []
        
        for itinerary in itineraries:
            # Extract key details
            price = itinerary.get('price', {}).get('formatted', 'N/A')
            legs = itinerary.get('legs', [])
            
            # Collect details for each leg
            for leg in legs:
                leg_info = {
                    'Itinerary ID': itinerary.get('id', 'N/A'),
                    'Price': price,
                    'Origin': leg.get('origin', {}).get('name', 'N/A'),
                    'Destination': leg.get('destination', {}).get('name', 'N/A'),
                    'Departure': leg.get('departure', 'N/A'),
                    'Arrival': leg.get('arrival', 'N/A'),
                    'Duration (minutes)': leg.get('durationInMinutes', 'N/A'),
                    'Carrier': ', '.join([carrier.get('name', 'N/A') for carrier in leg.get('carriers', {}).get('marketing', [])]),
                }
                processed_data.append(leg_info)
        
        # Create a DataFrame
        df = pd.DataFrame(processed_data)
        return df

    except Exception as e:
        print(f"Error processing data: {e}")
        return None

# Example usage

processed_df = process_itinerary_data(parsed_data)

df['Departure'] = df['Departure'].str.replace('T', ' ').str.slice(0, 16)
df['Arrival'] = df['Arrival'].str.replace('T', ' ').str.slice(0, 16)

# %%
df
# Out:
#       Price                        Origin                   Destination  \
# 0   ₹ 9,647  Indira Gandhi International                         Mumbai
# 1   ₹ 9,647                        Mumbai  Indira Gandhi International
# 2   ₹ 9,647  Indira Gandhi International                         Mumbai
# 3   ₹ 9,647                        Mumbai  Indira Gandhi International
# 4   ₹ 9,896  Indira Gandhi International                         Mumbai
# 5   ₹ 9,896                        Mumbai  Indira Gandhi International
# 6   ₹ 9,647  Indira Gandhi International                         Mumbai
# 7   ₹ 9,647                        Mumbai  Indira Gandhi International
# 8   ₹ 9,647  Indira Gandhi International                         Mumbai
# 9   ₹ 9,647                        Mumbai  Indira Gandhi International
# 10  ₹ 9,896  Indira Gandhi International                         Mumbai
# 11  ₹ 9,896                        Mumbai  Indira Gandhi International
# 12  ₹ 9,896  Indira Gandhi International                         Mumbai
# 13  ₹ 9,896                        Mumbai  Indira Gandhi International
# 14  ₹ 9,647  Indira Gandhi International                         Mumbai
# 15  ₹ 9,647                        Mumbai  Indira Gandhi International
# 16  ₹ 9,896  Indira Gandhi International                         Mumbai
# 17  ₹ 9,896                        Mumbai  Indira Gandhi International
# 18  ₹ 9,896  Indira Gandhi International                         Mumbai
# 19  ₹ 9,896                        Mumbai  Indira Gandhi International
#
#            Departure           Arrival  Duration (minutes) Carrier
# 0   2025-02-26 08:00  2025-02-26 10:20                 140  IndiGo
# 1   2025-02-27 19:00  2025-02-27 21:15                 135  IndiGo
# 2   2025-02-26 10:00  2025-02-26 12:20                 140  IndiGo
# 3   2025-02-27 19:00  2025-02-27 21:15                 135  IndiGo
# 4   2025-02-26 10:00  2025-02-26 12:20                 140  IndiGo
# 5   2025-02-27 17:00  2025-02-27 19:10                 130  IndiGo
# 6   2025-02-26 07:00  2025-02-26 09:15                 135  IndiGo
# 7   2025-02-27 19:00  2025-02-27 21:15                 135  IndiGo
# 8   2025-02-26 08:00  2025-02-26 10:20                 140  IndiGo
# 9   2025-02-27 20:00  2025-02-27 22:10                 130  IndiGo
# 10  2025-02-26 11:50  2025-02-26 14:10                 140  IndiGo
# 11  2025-02-27 17:00  2025-02-27 19:10                 130  IndiGo
# 12  2025-02-26 10:00  2025-02-26 12:20                 140  IndiGo
# 13  2025-02-27 18:00  2025-02-27 20:10                 130  IndiGo
# 14  2025-02-26 11:50  2025-02-26 14:10                 140  IndiGo
# 15  2025-02-27 19:00  2025-02-27 21:15                 135  IndiGo
# 16  2025-02-26 08:00  2025-02-26 10:20                 140  IndiGo
# 17  2025-02-27 18:00  2025-02-27 20:10                 130  IndiGo
# 18  2025-02-26 08:00  2025-02-26 10:20                 140  IndiGo
# 19  2025-02-27 17:00  2025-02-27 19:10                 130  IndiGo

# %%
# Step 1: Remove ₹ and commas, convert to integer
df['Price'] = df['Price'].str.replace('₹', '', regex=False)  # Remove ₹
df['Price'] = df['Price'].str.replace(',', '', regex=False)  # Remove commas
df['Price'] = df['Price'].astype(int)  # Convert to integer

# Step 2: Sort the DataFrame by the Price column
df = df.sort_values(by='Price', ascending=True)

# Reset index if needed
df = df.reset_index(drop=True)

# %%
df
# Out:
#     Price                        Origin                   Destination  \
# 0    9647  Indira Gandhi International                         Mumbai
# 1    9647                        Mumbai  Indira Gandhi International
# 2    9647  Indira Gandhi International                         Mumbai
# 3    9647  Indira Gandhi International                         Mumbai
# 4    9647                        Mumbai  Indira Gandhi International
# 5    9647  Indira Gandhi International                         Mumbai
# 6    9647                        Mumbai  Indira Gandhi International
# 7    9647                        Mumbai  Indira Gandhi International
# 8    9647  Indira Gandhi International                         Mumbai
# 9    9647                        Mumbai  Indira Gandhi International
# 10   9896  Indira Gandhi International                         Mumbai
# 11   9896  Indira Gandhi International                         Mumbai
# 12   9896  Indira Gandhi International                         Mumbai
# 13   9896                        Mumbai  Indira Gandhi International
# 14   9896  Indira Gandhi International                         Mumbai
# 15   9896                        Mumbai  Indira Gandhi International
# 16   9896  Indira Gandhi International                         Mumbai
# 17   9896                        Mumbai  Indira Gandhi International
# 18   9896                        Mumbai  Indira Gandhi International
# 19   9896                        Mumbai  Indira Gandhi International
#
#            Departure           Arrival  Duration (minutes) Carrier
# 0   2025-02-26 08:00  2025-02-26 10:20                 140  IndiGo
# 1   2025-02-27 19:00  2025-02-27 21:15                 135  IndiGo
# 2   2025-02-26 11:50  2025-02-26 14:10                 140  IndiGo
# 3   2025-02-26 08:00  2025-02-26 10:20                 140  IndiGo
# 4   2025-02-27 19:00  2025-02-27 21:15                 135  IndiGo
# 5   2025-02-26 07:00  2025-02-26 09:15                 135  IndiGo
# 6   2025-02-27 20:00  2025-02-27 22:10                 130  IndiGo
# 7   2025-02-27 19:00  2025-02-27 21:15                 135  IndiGo
# 8   2025-02-26 10:00  2025-02-26 12:20                 140  IndiGo
# 9   2025-02-27 19:00  2025-02-27 21:15                 135  IndiGo
# 10  2025-02-26 10:00  2025-02-26 12:20                 140  IndiGo
# 11  2025-02-26 08:00  2025-02-26 10:20                 140  IndiGo
# 12  2025-02-26 11:50  2025-02-26 14:10                 140  IndiGo
# 13  2025-02-27 17:00  2025-02-27 19:10                 130  IndiGo
# 14  2025-02-26 10:00  2025-02-26 12:20                 140  IndiGo
# 15  2025-02-27 18:00  2025-02-27 20:10                 130  IndiGo
# 16  2025-02-26 08:00  2025-02-26 10:20                 140  IndiGo
# 17  2025-02-27 18:00  2025-02-27 20:10                 130  IndiGo
# 18  2025-02-27 17:00  2025-02-27 19:10                 130  IndiGo
# 19  2025-02-27 17:00  2025-02-27 19:10                 130  IndiGo

# %%
# Save the DataFrame to a CSV file named 'flights.csv', overwriting if it exists
df.to_csv('flights.csv', index=False)

print("DataFrame has been successfully saved to 'flights.csv'.")
# Out:
# DataFrame has been successfully saved to 'flights.csv'.
