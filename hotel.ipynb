# %%
import requests
import json
dest_url = "https://booking-com15.p.rapidapi.com/api/v1/hotels/searchDestination"

dest_params = {
    "query": "Mumbai",  # Replace with your desired location
    "languagecode": "en-us"
}

# Headers
headers = {
	"x-rapidapi-key": "3cf4a51d9dmsh00a3b36b8746643p1d63cbjsn0a0868139292",
	"x-rapidapi-host": "booking-com15.p.rapidapi.com"
}

dest_response = requests.get(dest_url, headers=headers, params=dest_params)

formatted_dest_response = json.dumps(dest_response.json(), indent=4)

# %%
response_dict = json.loads(formatted_dest_response)

# Extract the first `dest_id`
dest_id = response_dict["data"][0]["dest_id"]

# Save it as a variable
print(f"The extracted dest_id is: {dest_id}")
# Out:
# The extracted dest_id is: -2092174

# %%
import requests
import json  # Import JSON module for formatting

url = "https://booking-com15.p.rapidapi.com/api/v1/hotels/searchHotels"

# Query Parameters
params = {
    "dest_id": dest_id,
    "search_type": "CITY",
    "arrival_date": "2024-12-23",
    "departure_date": "2024-12-24",
    "adults": 2,
    "room_qty": 1,
    "sort_by": "PRICE_ASC",
    "categories_filter": "budget",
    "units": "metric",
    "temperature_unit": "c",
    "languagecode": "en-us",
    "currency_code": "INR"
}

headers = {
	"x-rapidapi-key": "3cf4a51d9dmsh00a3b36b8746643p1d63cbjsn0a0868139292",
	"x-rapidapi-host": "booking-com15.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=params)

# Format the JSON response for readability
formatted_response = json.dumps(response.json(), indent=4)

# Print the readable JSON response
print(formatted_response)
# Out:
# {
#     "message": "You have exceeded the MONTHLY quota for requests on your current plan, BASIC. Upgrade your plan at https://rapidapi.com/DataCrawler/api/booking-com15"
# }

# %%
import pandas as pd

# Assuming `response` contains the JSON response from the API call
try:
    data = response.json()  # Parse the JSON response
    hotels = data.get('data', {}).get('hotels', [])  # Extract the 'hotels' list from the JSON
    
    # Extract relevant hotel details into a structured list
    hotel_list = []
    for hotel in hotels:
        property_data = hotel.get('property', {})
        price_breakdown = property_data.get('priceBreakdown', {})
        
        hotel_info = {
            "Hotel Name": property_data.get('name', 'N/A'),
            "Review Score": property_data.get('reviewScore', 'N/A'),
            "Review Word": property_data.get('reviewScoreWord', 'N/A'),
            "Review Count": property_data.get('reviewCount', 'N/A'),
            "Gross Price": price_breakdown.get('grossPrice', {}).get('value', 'N/A'),
            "Currency": price_breakdown.get('grossPrice', {}).get('currency', 'N/A'),
            "Excluded Taxes ": price_breakdown.get('excludedPrice', {}).get('value', 'N/A'),
            "Strikethrough Price ": price_breakdown.get('strikethroughPrice', {}).get('value', 'N/A'),
            "Check-in Date": property_data.get('checkinDate', 'N/A'),
            "Check-out Date": property_data.get('checkoutDate', 'N/A'),
            "Location (Latitude)": property_data.get('latitude', 'N/A'),
            "Location (Longitude)": property_data.get('longitude', 'N/A'),
            "Photo URL": property_data.get('photoUrls', ['N/A'])[0],  # Get the first photo URL
        }
        hotel_list.append(hotel_info)
    
    # Convert to DataFrame for easy display and manipulation
    df = pd.DataFrame(hotel_list)
    print(df)  # Display the DataFrame in the console
except Exception as e:
    print(f"Error processing data: {e}")
# Out:
#                                            Hotel Name  Review Score  \
# 0                FabHotel Atithi Residency I - Nr BKC           6.6
# 1                        Sun-n-Sand Mumbai Juhu Beach           7.3
# 2                  FabExpress Embassy Suites - Nr BKC           6.1
# 3    FabExpress Abad Inn - 700m from Gateway of India           7.0
# 4                            Hotel Bawa International           7.2
# 5                               Trident Nariman Point           8.7
# 6   Hotel Oriental Aster - Mumbai International Ai...           7.5
# 7                                       Taj Lands End           8.6
# 8                              Hotel Bawa Continental           7.9
# 9                                Trident Bandra Kurla           8.8
# 10                                      Hotel Linkway           8.3
# 11            Hotel Supreme Comforts - Mumbai Airport           8.0
# 12                                 Hotel Kemps Corner           7.7
# 13                                         The Resort           7.8
# 14                        The Taj Mahal Tower, Mumbai           9.1
# 15                                The Fern - Goregaon           7.6
# 16                                      Taj Santacruz           8.8
# 17                                  The Oberoi Mumbai           9.3
# 18  Fabhotel Glorify Palace - Nr Mumbai Internatio...           6.7
# 19      Treebo Premium Heritage Grand -Majiwada Thane           7.6
#
#    Review Word  Review Count  Gross Price Currency  Excluded Taxes   \
# 0     Pleasant            45      2005.69      INR       240.682795
# 1         Good           695     10000.00      INR      1800.000072
# 2     Pleasant           170      2436.83      INR       292.419593
# 3         Good           218      3120.03      INR       374.403592
# 4         Good           936      5250.00      INR       629.999986
# 5    Excellent          4480     15500.00      INR      2790.000111
# 6         Good           983      3499.00      INR       419.879991
# 7    Excellent          3266     11000.00      INR      1980.000079
# 8         Good           825      4500.00      INR       539.999988
# 9    Excellent          3573     11750.00      INR      2115.000084
# 10   Very Good           443      3200.00      INR       383.999991
# 11   Very Good           140      4824.00      INR       578.879987
# 12        Good           421      6480.00      INR       777.599983
# 13        Good           960      9736.55      INR      1752.579070
# 14   Wonderful          5254     14400.00      INR      2592.000103
# 15        Good           315      7643.22      INR      1375.779655
# 16   Excellent          2747     10250.00      INR      1845.000073
# 17   Wonderful          1995     23000.00      INR      4140.000165
# 18    Pleasant            87      1523.78      INR       182.853596
# 19        Good            33      4946.72      INR       593.606387
#
#    Strikethrough Price  Check-in Date Check-out Date  Location (Latitude)  \
# 0               4093.24    2024-12-23     2024-12-24            19.096049
# 1                   N/A    2024-12-23     2024-12-24            19.109488
# 2               4973.13    2024-12-23     2024-12-24            19.057730
# 3                6367.4    2024-12-23     2024-12-24            18.918525
# 4                   N/A    2024-12-23     2024-12-24            19.096377
# 5                   N/A    2024-12-23     2024-12-24            18.927651
# 6                   N/A    2024-12-23     2024-12-24            19.107919
# 7                   N/A    2024-12-23     2024-12-24            19.043707
# 8                   N/A    2024-12-23     2024-12-24            19.100571
# 9                   N/A    2024-12-23     2024-12-24            19.066640
# 10                  N/A    2024-12-23     2024-12-24            19.071824
# 11                 6030    2024-12-23     2024-12-24            19.107198
# 12                  N/A    2024-12-23     2024-12-24            18.964159
# 13                10249    2024-12-23     2024-12-24            19.173398
# 14                16000    2024-12-23     2024-12-24            18.921501
# 15                  N/A    2024-12-23     2024-12-24            19.162503
# 16                  N/A    2024-12-23     2024-12-24            19.092187
# 17                  N/A    2024-12-23     2024-12-24            18.927103
# 18              3109.76    2024-12-23     2024-12-24            19.097011
# 19                11504    2024-12-23     2024-12-24            19.232463
#
#     Location (Longitude)                                          Photo URL
# 0              72.883702  https://cf.bstatic.com/xdata/images/hotel/squa...
# 1              72.824343  https://cf.bstatic.com/xdata/images/hotel/squa...
# 2              72.870410  https://cf.bstatic.com/xdata/images/hotel/squa...
# 3              72.831311  https://cf.bstatic.com/xdata/images/hotel/squa...
# 4              72.853711  https://cf.bstatic.com/xdata/images/hotel/squa...
# 5              72.820580  https://cf.bstatic.com/xdata/images/hotel/squa...
# 6              72.861626  https://cf.bstatic.com/xdata/images/hotel/squa...
# 7              72.819038  https://cf.bstatic.com/xdata/images/hotel/squa...
# 8              72.827481  https://cf.bstatic.com/xdata/images/hotel/squa...
# 9              72.867529  https://cf.bstatic.com/xdata/images/hotel/squa...
# 10             72.834340  https://cf.bstatic.com/xdata/images/hotel/squa...
# 11             72.859575  https://cf.bstatic.com/xdata/images/hotel/squa...
# 12             72.806297  https://cf.bstatic.com/xdata/images/hotel/squa...
# 13             72.796051  https://cf.bstatic.com/xdata/images/hotel/squa...
# 14             72.833290  https://cf.bstatic.com/xdata/images/hotel/squa...
# 15             72.857013  https://cf.bstatic.com/xdata/images/hotel/squa...
# 16             72.853408  https://cf.bstatic.com/xdata/images/hotel/squa...
# 17             72.820280  https://cf.bstatic.com/xdata/images/hotel/squa...
# 18             72.883871  https://cf.bstatic.com/xdata/images/hotel/squa...
# 19             72.984062  https://cf.bstatic.com/xdata/images/hotel/squa...

# %%
df
# Out:
#                                            Hotel Name  Review Score  \
# 0                FabHotel Atithi Residency I - Nr BKC           6.6
# 1                        Sun-n-Sand Mumbai Juhu Beach           7.3
# 2                  FabExpress Embassy Suites - Nr BKC           6.1
# 3    FabExpress Abad Inn - 700m from Gateway of India           7.0
# 4                            Hotel Bawa International           7.2
# 5                               Trident Nariman Point           8.7
# 6   Hotel Oriental Aster - Mumbai International Ai...           7.5
# 7                                       Taj Lands End           8.6
# 8                              Hotel Bawa Continental           7.9
# 9                                Trident Bandra Kurla           8.8
# 10                                      Hotel Linkway           8.3
# 11            Hotel Supreme Comforts - Mumbai Airport           8.0
# 12                                 Hotel Kemps Corner           7.7
# 13                                         The Resort           7.8
# 14                        The Taj Mahal Tower, Mumbai           9.1
# 15                                The Fern - Goregaon           7.6
# 16                                      Taj Santacruz           8.8
# 17                                  The Oberoi Mumbai           9.3
# 18  Fabhotel Glorify Palace - Nr Mumbai Internatio...           6.7
# 19      Treebo Premium Heritage Grand -Majiwada Thane           7.6
#
#    Review Word  Review Count  Gross Price Currency  Excluded Taxes   \
# 0     Pleasant            45      2005.69      INR       240.682795
# 1         Good           695     10000.00      INR      1800.000072
# 2     Pleasant           170      2436.83      INR       292.419593
# 3         Good           218      3120.03      INR       374.403592
# 4         Good           936      5250.00      INR       629.999986
# 5    Excellent          4480     15500.00      INR      2790.000111
# 6         Good           983      3499.00      INR       419.879991
# 7    Excellent          3266     11000.00      INR      1980.000079
# 8         Good           825      4500.00      INR       539.999988
# 9    Excellent          3573     11750.00      INR      2115.000084
# 10   Very Good           443      3200.00      INR       383.999991
# 11   Very Good           140      4824.00      INR       578.879987
# 12        Good           421      6480.00      INR       777.599983
# 13        Good           960      9736.55      INR      1752.579070
# 14   Wonderful          5254     14400.00      INR      2592.000103
# 15        Good           315      7643.22      INR      1375.779655
# 16   Excellent          2747     10250.00      INR      1845.000073
# 17   Wonderful          1995     23000.00      INR      4140.000165
# 18    Pleasant            87      1523.78      INR       182.853596
# 19        Good            33      4946.72      INR       593.606387
#
#    Strikethrough Price  Check-in Date Check-out Date  Location (Latitude)  \
# 0               4093.24    2024-12-23     2024-12-24            19.096049
# 1                   N/A    2024-12-23     2024-12-24            19.109488
# 2               4973.13    2024-12-23     2024-12-24            19.057730
# 3                6367.4    2024-12-23     2024-12-24            18.918525
# 4                   N/A    2024-12-23     2024-12-24            19.096377
# 5                   N/A    2024-12-23     2024-12-24            18.927651
# 6                   N/A    2024-12-23     2024-12-24            19.107919
# 7                   N/A    2024-12-23     2024-12-24            19.043707
# 8                   N/A    2024-12-23     2024-12-24            19.100571
# 9                   N/A    2024-12-23     2024-12-24            19.066640
# 10                  N/A    2024-12-23     2024-12-24            19.071824
# 11                 6030    2024-12-23     2024-12-24            19.107198
# 12                  N/A    2024-12-23     2024-12-24            18.964159
# 13                10249    2024-12-23     2024-12-24            19.173398
# 14                16000    2024-12-23     2024-12-24            18.921501
# 15                  N/A    2024-12-23     2024-12-24            19.162503
# 16                  N/A    2024-12-23     2024-12-24            19.092187
# 17                  N/A    2024-12-23     2024-12-24            18.927103
# 18              3109.76    2024-12-23     2024-12-24            19.097011
# 19                11504    2024-12-23     2024-12-24            19.232463
#
#     Location (Longitude)                                          Photo URL
# 0              72.883702  https://cf.bstatic.com/xdata/images/hotel/squa...
# 1              72.824343  https://cf.bstatic.com/xdata/images/hotel/squa...
# 2              72.870410  https://cf.bstatic.com/xdata/images/hotel/squa...
# 3              72.831311  https://cf.bstatic.com/xdata/images/hotel/squa...
# 4              72.853711  https://cf.bstatic.com/xdata/images/hotel/squa...
# 5              72.820580  https://cf.bstatic.com/xdata/images/hotel/squa...
# 6              72.861626  https://cf.bstatic.com/xdata/images/hotel/squa...
# 7              72.819038  https://cf.bstatic.com/xdata/images/hotel/squa...
# 8              72.827481  https://cf.bstatic.com/xdata/images/hotel/squa...
# 9              72.867529  https://cf.bstatic.com/xdata/images/hotel/squa...
# 10             72.834340  https://cf.bstatic.com/xdata/images/hotel/squa...
# 11             72.859575  https://cf.bstatic.com/xdata/images/hotel/squa...
# 12             72.806297  https://cf.bstatic.com/xdata/images/hotel/squa...
# 13             72.796051  https://cf.bstatic.com/xdata/images/hotel/squa...
# 14             72.833290  https://cf.bstatic.com/xdata/images/hotel/squa...
# 15             72.857013  https://cf.bstatic.com/xdata/images/hotel/squa...
# 16             72.853408  https://cf.bstatic.com/xdata/images/hotel/squa...
# 17             72.820280  https://cf.bstatic.com/xdata/images/hotel/squa...
# 18             72.883871  https://cf.bstatic.com/xdata/images/hotel/squa...
# 19             72.984062  https://cf.bstatic.com/xdata/images/hotel/squa...

# %%
df1 = df[["Hotel Name", "Gross Price", "Check-in Date", "Check-out Date", "Photo URL"]]

# %%
df1
# Out:
#                                            Hotel Name  Gross Price  \
# 0                FabHotel Atithi Residency I - Nr BKC      2005.69
# 1                        Sun-n-Sand Mumbai Juhu Beach     10000.00
# 2                  FabExpress Embassy Suites - Nr BKC      2436.83
# 3    FabExpress Abad Inn - 700m from Gateway of India      3120.03
# 4                            Hotel Bawa International      5250.00
# 5                               Trident Nariman Point     15500.00
# 6   Hotel Oriental Aster - Mumbai International Ai...      3499.00
# 7                                       Taj Lands End     11000.00
# 8                              Hotel Bawa Continental      4500.00
# 9                                Trident Bandra Kurla     11750.00
# 10                                      Hotel Linkway      3200.00
# 11            Hotel Supreme Comforts - Mumbai Airport      4824.00
# 12                                 Hotel Kemps Corner      6480.00
# 13                                         The Resort      9736.55
# 14                        The Taj Mahal Tower, Mumbai     14400.00
# 15                                The Fern - Goregaon      7643.22
# 16                                      Taj Santacruz     10250.00
# 17                                  The Oberoi Mumbai     23000.00
# 18  Fabhotel Glorify Palace - Nr Mumbai Internatio...      1523.78
# 19      Treebo Premium Heritage Grand -Majiwada Thane      4946.72
#
#    Check-in Date Check-out Date  \
# 0     2024-12-23     2024-12-24
# 1     2024-12-23     2024-12-24
# 2     2024-12-23     2024-12-24
# 3     2024-12-23     2024-12-24
# 4     2024-12-23     2024-12-24
# 5     2024-12-23     2024-12-24
# 6     2024-12-23     2024-12-24
# 7     2024-12-23     2024-12-24
# 8     2024-12-23     2024-12-24
# 9     2024-12-23     2024-12-24
# 10    2024-12-23     2024-12-24
# 11    2024-12-23     2024-12-24
# 12    2024-12-23     2024-12-24
# 13    2024-12-23     2024-12-24
# 14    2024-12-23     2024-12-24
# 15    2024-12-23     2024-12-24
# 16    2024-12-23     2024-12-24
# 17    2024-12-23     2024-12-24
# 18    2024-12-23     2024-12-24
# 19    2024-12-23     2024-12-24
#
#                                             Photo URL
# 0   https://cf.bstatic.com/xdata/images/hotel/squa...
# 1   https://cf.bstatic.com/xdata/images/hotel/squa...
# 2   https://cf.bstatic.com/xdata/images/hotel/squa...
# 3   https://cf.bstatic.com/xdata/images/hotel/squa...
# 4   https://cf.bstatic.com/xdata/images/hotel/squa...
# 5   https://cf.bstatic.com/xdata/images/hotel/squa...
# 6   https://cf.bstatic.com/xdata/images/hotel/squa...
# 7   https://cf.bstatic.com/xdata/images/hotel/squa...
# 8   https://cf.bstatic.com/xdata/images/hotel/squa...
# 9   https://cf.bstatic.com/xdata/images/hotel/squa...
# 10  https://cf.bstatic.com/xdata/images/hotel/squa...
# 11  https://cf.bstatic.com/xdata/images/hotel/squa...
# 12  https://cf.bstatic.com/xdata/images/hotel/squa...
# 13  https://cf.bstatic.com/xdata/images/hotel/squa...
# 14  https://cf.bstatic.com/xdata/images/hotel/squa...
# 15  https://cf.bstatic.com/xdata/images/hotel/squa...
# 16  https://cf.bstatic.com/xdata/images/hotel/squa...
# 17  https://cf.bstatic.com/xdata/images/hotel/squa...
# 18  https://cf.bstatic.com/xdata/images/hotel/squa...
# 19  https://cf.bstatic.com/xdata/images/hotel/squa...

# %%
# Sort the DataFrame by 'Gross Price' in ascending order
df1 = df1.sort_values(by="Gross Price", ascending=True)

# Reset the index if required
df1 = df1.reset_index(drop=True)
df1
# Out:
#                                            Hotel Name  Gross Price  \
# 0   Fabhotel Glorify Palace - Nr Mumbai Internatio...      1523.78
# 1                FabHotel Atithi Residency I - Nr BKC      2005.69
# 2                  FabExpress Embassy Suites - Nr BKC      2436.83
# 3    FabExpress Abad Inn - 700m from Gateway of India      3120.03
# 4                                       Hotel Linkway      3200.00
# 5   Hotel Oriental Aster - Mumbai International Ai...      3499.00
# 6                              Hotel Bawa Continental      4500.00
# 7             Hotel Supreme Comforts - Mumbai Airport      4824.00
# 8       Treebo Premium Heritage Grand -Majiwada Thane      4946.72
# 9                            Hotel Bawa International      5250.00
# 10                                 Hotel Kemps Corner      6480.00
# 11                                The Fern - Goregaon      7643.22
# 12                                         The Resort      9736.55
# 13                       Sun-n-Sand Mumbai Juhu Beach     10000.00
# 14                                      Taj Santacruz     10250.00
# 15                                      Taj Lands End     11000.00
# 16                               Trident Bandra Kurla     11750.00
# 17                        The Taj Mahal Tower, Mumbai     14400.00
# 18                              Trident Nariman Point     15500.00
# 19                                  The Oberoi Mumbai     23000.00
#
#    Check-in Date Check-out Date  \
# 0     2024-12-23     2024-12-24
# 1     2024-12-23     2024-12-24
# 2     2024-12-23     2024-12-24
# 3     2024-12-23     2024-12-24
# 4     2024-12-23     2024-12-24
# 5     2024-12-23     2024-12-24
# 6     2024-12-23     2024-12-24
# 7     2024-12-23     2024-12-24
# 8     2024-12-23     2024-12-24
# 9     2024-12-23     2024-12-24
# 10    2024-12-23     2024-12-24
# 11    2024-12-23     2024-12-24
# 12    2024-12-23     2024-12-24
# 13    2024-12-23     2024-12-24
# 14    2024-12-23     2024-12-24
# 15    2024-12-23     2024-12-24
# 16    2024-12-23     2024-12-24
# 17    2024-12-23     2024-12-24
# 18    2024-12-23     2024-12-24
# 19    2024-12-23     2024-12-24
#
#                                             Photo URL
# 0   https://cf.bstatic.com/xdata/images/hotel/squa...
# 1   https://cf.bstatic.com/xdata/images/hotel/squa...
# 2   https://cf.bstatic.com/xdata/images/hotel/squa...
# 3   https://cf.bstatic.com/xdata/images/hotel/squa...
# 4   https://cf.bstatic.com/xdata/images/hotel/squa...
# 5   https://cf.bstatic.com/xdata/images/hotel/squa...
# 6   https://cf.bstatic.com/xdata/images/hotel/squa...
# 7   https://cf.bstatic.com/xdata/images/hotel/squa...
# 8   https://cf.bstatic.com/xdata/images/hotel/squa...
# 9   https://cf.bstatic.com/xdata/images/hotel/squa...
# 10  https://cf.bstatic.com/xdata/images/hotel/squa...
# 11  https://cf.bstatic.com/xdata/images/hotel/squa...
# 12  https://cf.bstatic.com/xdata/images/hotel/squa...
# 13  https://cf.bstatic.com/xdata/images/hotel/squa...
# 14  https://cf.bstatic.com/xdata/images/hotel/squa...
# 15  https://cf.bstatic.com/xdata/images/hotel/squa...
# 16  https://cf.bstatic.com/xdata/images/hotel/squa...
# 17  https://cf.bstatic.com/xdata/images/hotel/squa...
# 18  https://cf.bstatic.com/xdata/images/hotel/squa...
# 19  https://cf.bstatic.com/xdata/images/hotel/squa...

# %%
df1.to_csv('hotels.csv', index=False)

print("DataFrame has been successfully saved to 'hotels.csv'.")
# Out:
# DataFrame has been successfully saved to 'hotels.csv'.
