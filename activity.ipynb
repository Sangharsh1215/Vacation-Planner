# %%
import requests

url = "https://travel-guide-api-city-guide-top-places.p.rapidapi.com/check"

querystring = {"noqueue":"1"}

payload = {
	"region": "Mumbai",
	"language": "en",
	"interests": ["historical", "cultural", "food"]
}
headers = {
	"x-rapidapi-key": "7f1bea6bb4msh78929f2c5e64eefp1988d4jsnece92c6405d1",
	"x-rapidapi-host": "travel-guide-api-city-guide-top-places.p.rapidapi.com",
	"Content-Type": "application/json"
}

response = requests.post(url, json=payload, headers=headers, params=querystring)

print(response.json())
# Out:
# {'result': [{'name': 'Gateway of India', 'description': 'An iconic archway built in 1924 to commemorate the visit of King George V and Queen Mary to India. It overlooks the Arabian Sea and is a popular tourist destination.', 'coordinates': {'latitude': '18.9218', 'longitude': '72.8347'}, 'type': 'historical', 'comments': 'Visit early in the morning to avoid crowds and enjoy the scenic views. Boat rides are available from this location, taking you to Elephanta Island.'}, {'name': 'Chhatrapati Shivaji Maharaj Terminus', 'description': 'A UNESCO World Heritage Site and an excellent example of Victorian Gothic architecture in India, this railway terminus is one of the busiest railway stations in the country.', 'coordinates': {'latitude': '18.9402', 'longitude': '72.8348'}, 'type': 'historical', 'comments': 'Take a guided tour to learn about its history and architecture. The area around the terminus is bustling with activity, so be sure to take some time to explore.'}, {'name': 'Elephanta Caves', 'description': 'A network of sculpted caves located on Elephanta Island, these caves are famous for their rock-cut sculptures depicting Hindu deities.', 'coordinates': {'latitude': '18.5820', 'longitude': '72.8998'}, 'type': 'cultural', 'comments': 'The best time to visit is during the cooler months from November to February. Take a ferry from the Gateway of India for a scenic journey to the island.'}, {'name': 'Kala Ghoda Arts Precinct', 'description': "A vibrant area known for its rich cultural heritage, art galleries, museums, and boutiques. It's a hub for artists and art lovers.", 'coordinates': {'latitude': '18.9214', 'longitude': '72.8322'}, 'type': 'cultural', 'comments': 'Plan your visit around the Kala Ghoda Arts Festival held annually in February, showcasing local art, dance, and music.'}, {'name': 'Mumbai Street Food', 'description': 'Mumbai is famous for its street food, featuring a mix of flavors and cuisines. Must-try items include Vada Pav, Pani Puri, and Pav Bhaji.', 'coordinates': {'latitude': '19.0760', 'longitude': '72.8777'}, 'type': 'food', 'comments': "Visit local street food stalls in Juhu Chowpatty or CST area. It's best to eat where the locals do and ensure the food stall appears busy, reflecting freshness."}, {'name': 'Crawford Market', 'description': 'A bustling market known for fresh produce, spices, and household goods. The market is famous for its architecture and vibrant atmosphere.', 'coordinates': {'latitude': '18.9613', 'longitude': '72.8345'}, 'type': 'cultural', 'comments': "Take your time exploring the various stalls, and don't miss the opportunity to sample fresh fruits and snacks available throughout the market."}], 'cacheTime': 1735076214573}

# %%
import json
formatted_response = json.dumps(response.json(), indent=4)

# Print the readable JSON response
print(formatted_response)
# Out:
# {
#     "result": [
#         {
#             "name": "Gateway of India",
#             "description": "An iconic archway built in 1924 to commemorate the visit of King George V and Queen Mary to India. It overlooks the Arabian Sea and is a popular tourist destination.",
#             "coordinates": {
#                 "latitude": "18.9218",
#                 "longitude": "72.8347"
#             },
#             "type": "historical",
#             "comments": "Visit early in the morning to avoid crowds and enjoy the scenic views. Boat rides are available from this location, taking you to Elephanta Island."
#         },
#         {
#             "name": "Chhatrapati Shivaji Maharaj Terminus",
#             "description": "A UNESCO World Heritage Site and an excellent example of Victorian Gothic architecture in India, this railway terminus is one of the busiest railway stations in the country.",
#             "coordinates": {
#                 "latitude": "18.9402",
#                 "longitude": "72.8348"
#             },
#             "type": "historical",
#             "comments": "Take a guided tour to learn about its history and architecture. The area around the terminus is bustling with activity, so be sure to take some time to explore."
#         },
#         {
#             "name": "Elephanta Caves",
#             "description": "A network of sculpted caves located on Elephanta Island, these caves are famous for their rock-cut sculptures depicting Hindu deities.",
#             "coordinates": {
#                 "latitude": "18.5820",
#                 "longitude": "72.8998"
#             },
#             "type": "cultural",
#             "comments": "The best time to visit is during the cooler months from November to February. Take a ferry from the Gateway of India for a scenic journey to the island."
#         },
#         {
#             "name": "Kala Ghoda Arts Precinct",
#             "description": "A vibrant area known for its rich cultural heritage, art galleries, museums, and boutiques. It's a hub for artists and art lovers.",
#             "coordinates": {
#                 "latitude": "18.9214",
#                 "longitude": "72.8322"
#             },
#             "type": "cultural",
#             "comments": "Plan your visit around the Kala Ghoda Arts Festival held annually in February, showcasing local art, dance, and music."
#         },
#         {
#             "name": "Mumbai Street Food",
#             "description": "Mumbai is famous for its street food, featuring a mix of flavors and cuisines. Must-try items include Vada Pav, Pani Puri, and Pav Bhaji.",
#             "coordinates": {
#                 "latitude": "19.0760",
#                 "longitude": "72.8777"
#             },
#             "type": "food",
#             "comments": "Visit local street food stalls in Juhu Chowpatty or CST area. It's best to eat where the locals do and ensure the food stall appears busy, reflecting freshness."
#         },
#         {
#             "name": "Crawford Market",
#             "description": "A bustling market known for fresh produce, spices, and household goods. The market is famous for its architecture and vibrant atmosphere.",
#             "coordinates": {
#                 "latitude": "18.9613",
#                 "longitude": "72.8345"
#             },
#             "type": "cultural",
#             "comments": "Take your time exploring the various stalls, and don't miss the opportunity to sample fresh fruits and snacks available throughout the market."
#         }
#     ],
#     "cacheTime": 1735076214573
# }

# %%
import pandas as pd

# The response JSON from the API
response_data = response.json()

# Extract the 'result' data from the response
places_data = response_data.get("result", [])

# Convert the list of places data into a DataFrame
df = pd.DataFrame(places_data)

# If the coordinates are in a nested dictionary, expand them into separate columns
df_coordinates = pd.json_normalize(df['coordinates'])
df = pd.concat([df.drop(columns=['coordinates']), df_coordinates], axis=1)

df
# Out:
#                                    name  \
# 0                      Gateway of India
# 1  Chhatrapati Shivaji Maharaj Terminus
# 2                       Elephanta Caves
# 3              Kala Ghoda Arts Precinct
# 4                    Mumbai Street Food
# 5                       Crawford Market
#
#                                          description        type  \
# 0  An iconic archway built in 1924 to commemorate...  historical
# 1  A UNESCO World Heritage Site and an excellent ...  historical
# 2  A network of sculpted caves located on Elephan...    cultural
# 3  A vibrant area known for its rich cultural her...    cultural
# 4  Mumbai is famous for its street food, featurin...        food
# 5  A bustling market known for fresh produce, spi...    cultural
#
#                                             comments latitude longitude
# 0  Visit early in the morning to avoid crowds and...  18.9218   72.8347
# 1  Take a guided tour to learn about its history ...  18.9402   72.8348
# 2  The best time to visit is during the cooler mo...  18.5820   72.8998
# 3  Plan your visit around the Kala Ghoda Arts Fes...  18.9214   72.8322
# 4  Visit local street food stalls in Juhu Chowpat...  19.0760   72.8777
# 5  Take your time exploring the various stalls, a...  18.9613   72.8345

# %%
df.to_csv('Activity.csv', index=False)

print("DataFrame has been successfully saved to 'Activity.csv'.")
# Out:
# DataFrame has been successfully saved to 'Activity.csv'.
